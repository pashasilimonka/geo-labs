# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from geopandas import GeoSeries

gdf = gpd.read_file("./poland_Provinces_level_1/poland_Provinces_level_1.shp")

gdf.plot()
plt.show()

print(gdf.columns)

# Вивід перших 5 записів
print(gdf.head())

# Обчислення меж (bounding box)
minx, miny, maxx, maxy = gdf.total_bounds
print("Найзахідніша точка (longitude):", minx)
print("Найсхідніша точка (longitude):", maxx)



area = int(input(f"Оберіть область для якої знайти центральну точку від 1 до ${len(gdf)}"))

obj1 = gdf.iloc[area-1]

centroid = obj1.geometry.centroid

print("Центральна точка:", centroid)
centroid_gdf = gpd.GeoDataFrame(geometry=[centroid], crs=gdf.crs)

# Побудувати мапу
ax = gdf.plot(color='lightblue', edgecolor='black')
centroid_gdf.plot(ax=ax, color='red', markersize=50)
plt.show()
# Out:
# Index(['shape1', 'shapeiso', 'shapeid', 'shapegroup', 'shapetype', 'gid',
#        'shape0', 'geometry'],
#       dtype='object')
#                        shape1 shapeiso                  shapeid shapegroup  \
# 0   Subcarpathian Voivodeship    PL-PK  17162690B44985096553766        POL
# 1       Podlaskie Voivodeship    PL-PD  17162690B23777949290372        POL
# 2            Łodź Voivodeship    PL-LD  17162690B86810837764805        POL
# 3  Lower Silesian Voivodeship    PL-DS   17162690B9130125042960        POL
# 4           Opole Voivodeship    PL-OP  17162690B67719337891950        POL
#
#   shapetype  gid  shape0                                           geometry
# 0      ADM1    1  poland  POLYGON ((21.20883 50.3549, 21.20963 50.35486,...
# 1      ADM1    2  poland  POLYGON ((21.61295 53.48083, 21.61795 53.48077...
# 2      ADM1    3  poland  POLYGON ((19.04712 52.3328, 19.04713 52.33284,...
# 3      ADM1    4  poland  POLYGON ((14.97418 51.36395, 14.97476 51.36399...
# 4      ADM1    5  poland  POLYGON ((18.16369 51.17252, 18.16384 51.17214...
# Найзахідніша точка (longitude): 14.5341205
# Найсхідніша точка (longitude): 23.9462701
# Центральна точка: POINT (22.169082089352933 49.9536852378464)

# %%
5
